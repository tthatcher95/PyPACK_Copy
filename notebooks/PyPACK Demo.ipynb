# %%
from libpypack.locations import map_locations
from libpypack.visualization import generate_maps
from libpypack.visualization import heatmap
from libpypack.visualization import choropleth
from libpypack.locations import webpage_locations
# Out:
# Using TensorFlow backend.

# %%
from time import process_time 
t1_start = process_time()
tweet_df = map_locations.locations_df(csv_file="twitter_test.csv", sep=',')
t1_end = process_time()
print("Elapsed time during the whole program in seconds:", t1_end-t1_start)
# Out:
# /Users/thatcher/anaconda3/envs/datavis/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 953/953 [04:29<00:00,  3.54it/s]
# Elapsed time during the whole program in seconds: 375.54024

# %%
generate_maps.generate_overlay_plot(tweet_df)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1b85f5b38>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1b85f5b38>)

# %%
gdf = generate_maps.get_loc_gdf(tweet_df)

# %%
heatmap.heatmap(gdf)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
choropleth.choropleth_map(gdf)

# %%
web_df = webpage_locations.extract_webpage_locations(tweet_df)
webpage_locations.map_web_locations(web_df)
# Out:
# HTTP Error 400: Bad Request
# HTTP Error 404: Not Found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# HTTP Error 400: Bad Request
# HTTP Error 410: Gone
# HTTP Error 410: Gone
# HTTP Error 403: Forbidden
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# HTTP Error 404: Not Found
#                                                                                               Headers  \
# http://dlvr.it/Qmfy4V                               [Engel & V\xc3\xb6lkers Florida Launch Ground-...
# https://twitter.com/i/web/status/10492669160392...  [Saved searches\n, Tweets\n, \n    Food4Thaugh...
# https://larep.it/2IJ4B5C                            [\n, Menu di navigazione\n, \n\t\t\t\t\t\n\t\t...
# https://twitter.com/i/web/status/10492669333240...  [Saved searches\n, Tweets\n, \n    Ashley Mood...
# https://twitter.com/i/web/status/10492669420187...  [Saved searches\n, Tweets\n, \n    Veronica Gi...
# ...                                                                                               ...
# https://twitter.com/i/web/status/10492676970648...  [Saved searches\n, Tweets\n, \n    Karen Marti...
# https://twitter.com/i/web/status/10492677052060...  [Saved searches\n, Tweets\n, \n    afriend\n\n...
# https://twitter.com/i/web/status/10492677110568...  [Saved searches\n, Tweets\n, \n    Ron Kemmere...
# https://twitter.com/i/web/status/10492677112331...  [Saved searches\n, Tweets\n, \n    Niya Kight\...
# https://twitter.com/i/web/status/10492677240048...  [Saved searches\n, Tweets\n, \n    dlbolt \xf0...
#
#                                                                                            Paragraphs  \
# http://dlvr.it/Qmfy4V                               [NAPLES, Fla., Oct. 8, 2018 /PRNewswire-PRWeb/...
# https://twitter.com/i/web/status/10492669160392...  [We\'ve detected that JavaScript is disabled i...
# https://larep.it/2IJ4B5C                            [Il razzo riutilizzabile della compagnia di El...
# https://twitter.com/i/web/status/10492669333240...  [We\'ve detected that JavaScript is disabled i...
# https://twitter.com/i/web/status/10492669420187...  [We\'ve detected that JavaScript is disabled i...
# ...                                                                                               ...
# https://twitter.com/i/web/status/10492676970648...  [We\'ve detected that JavaScript is disabled i...
# https://twitter.com/i/web/status/10492677052060...  [We\'ve detected that JavaScript is disabled i...
# https://twitter.com/i/web/status/10492677110568...  [We\'ve detected that JavaScript is disabled i...
# https://twitter.com/i/web/status/10492677112331...  [We\'ve detected that JavaScript is disabled i...
# https://twitter.com/i/web/status/10492677240048...  [We\'ve detected that JavaScript is disabled i...
#
#                                                                                             Para_Locs
# http://dlvr.it/Qmfy4V                               {'Florida': ('28.75054', '-82.5001'), 'Boca Ra...
# https://twitter.com/i/web/status/10492669160392...     {'Little America': ('41.54357', '-109.85903')}
# https://larep.it/2IJ4B5C                                                                           {}
# https://twitter.com/i/web/status/10492669333240...              {'Florida': ('28.75054', '-82.5001')}
# https://twitter.com/i/web/status/10492669420187...      {'Brevard County': ('28.30031', '-80.70121')}
# ...                                                                                               ...
# https://twitter.com/i/web/status/10492676970648...     {'Charlottesville': ('38.02931', '-78.47668')}
# https://twitter.com/i/web/status/10492677052060...            {'Kentucky': ('38.20042', '-84.87762')}
# https://twitter.com/i/web/status/10492677110568...             {'New York': ('43.00035', '-75.4999')}
# https://twitter.com/i/web/status/10492677112331...  {'Washington': ('47.50012', '-120.50147'), 'Co...
# https://twitter.com/i/web/status/10492677240048...           {'Tennessee': ('35.75035', '-86.25027')}
#
# [140 rows x 3 columns]

# %%
web_gdf = generate_maps.get_loc_gdf(web_df, column_name='Para_Locs')
choropleth.choropleth_map(web_gdf)

# %%
heatmap.heatmap(web_gdf)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
